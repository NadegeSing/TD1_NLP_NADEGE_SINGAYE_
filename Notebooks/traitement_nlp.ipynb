# %% [markdown]
# # **TD : Collecte des Données en Python pour le Traitement du Langage Naturel (NLP)**
# Objectifs du TD
# -	Comprendre les méthodes de collecte de données pour le NLP.
# -	Manipuler des outils pour extraire des textes à partir de sources variées.
# -	Explorer les sources de données en ligne et apprendre à extraire des informations.
# -	Durée : 1h30 Prérequis
# -	Python 3.7+
# -	Bibliothèques nécessaires : Requests, BeautifulSoup, Pandas.
# Plan du TD
# 1. Introduction et mise en place
# 2. Extraction de données à partir d’une API
# 3. Web scraping de textes

# %% [markdown]
# **1.	Pour commencer**
#
# L’objectif de ce TD est de collecter des données textuelles à partir de différentes sources et de les préparer pour des applications NLP.

# %% [markdown]
# -	**Quelles sont les principales sources de données textuelles pour le NLP?**
#
# Le Natural Language Processing ou traitement du langage naturel désigne la capacité d’un programme informatique à comprendre et traiter le langage humain. Ce traitement porte sur l’interaction entre un humain et un ordinateur. Cela permet de traiter le langage naturel tel qu’il est parlé et écrit. Elle permet aux machines de comprendre, d'interpréter et de générer du langage humain de manière significative.
#
# -	**Pourquoi la collecte de données est-elle essentielle pour le NLP?**

# %% [markdown]
# **2. Extraction de données à partir d’une API**
#
# Pour ce TD, nous utiliserons une API comme NewsAPI, une API gratuite pour
# récupérer des articles d’actualité.

# %% [markdown]
# **Étapes à suivre :**
#
# - Créer un compte API et récupérer une clé API.
#
# - Effectuer une requête pour collecter des articles sur un thème donné.
#
# ***Requêtes : HTTP pour les humains***
#
# *Requests vous permet d’envoyer des requêtes HTTP*

# %%
pip install newsapi-python
# Out:
# Collecting newsapi-python
#   Downloading newsapi_python-0.2.7-py2.py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: requests<3.0.0 in d:\anacon\lib\site-packages (from newsapi-python) (2.32.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anacon\lib\site-packages (from requests<3.0.0->newsapi-python) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\anacon\lib\site-packages (from requests<3.0.0->newsapi-python) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anacon\lib\site-packages (from requests<3.0.0->newsapi-python) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anacon\lib\site-packages (from requests<3.0.0->newsapi-python) (2024.7.4)
# Downloading newsapi_python-0.2.7-py2.py3-none-any.whl (7.9 kB)
# Installing collected packages: newsapi-python
# Successfully installed newsapi-python-0.2.7
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests # Requests est une bibliothèque HTTP élégante
import json #  lightweight data interchange format that is easy for humans to read and write, and easy for machines to parse and generate. 

url = ('https://newsapi.org/v2/everything?'
       'q=Pokemon&'  # sujet d'article 
       'from=2019!!&' # année 
       'sortBy=popularity&'
       'apiKey=b684c34a769047de951b0009188bc981') # clé API

r = requests.get(url)

print(r.json())
print(r.status_code)
print(r.headers['content-type'])
print(r.encoding)
# Out:
# {'status': 'ok', 'totalResults': 967, 'articles': [{'source': {'id': None, 'name': 'Yahoo Entertainment'}, 'author': 'Jeremy Gan', 'title': 'The Chinese version of the Nintendo Switch won’t be able to access the eShop in 2026', 'description': 'If you didn’t know, Tencent (which is, among other things, the world’s biggest video game vendor) is the one that brought the Nintendo Switch to China\r\n in 2019. These Chinese versions of the console have access to fewer games, and they also can’t connect wit…', 'url': 'https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_abfc57ed-3dbc-4ccd-abe7-47f379542767', 'urlToImage': None, 'publishedAt': '2024-11-26T16:32:46Z', 'content': "If you click 'Accept all', we and our partners, including 237 who are part of the IAB Transparency &amp; Consent Framework, will also store and/or access information on a device (in other words, use … [+678 chars]"}, {'source': {'id': None, 'name': 'CNET'}, 'author': 'Jason Coles', 'title': 'Give a Pokemon Fan Something They Don’t Have With This Pikachu Ramen Bowl for Just $10', 'description': "Grab this ceramic bowl while it's 58% off thanks to this Black Friday deal at Amazon.", 'url': 'https://www.cnet.com/deals/give-a-pokemon-fan-something-they-dont-have-with-this-pikachu-ramen-bowl-for-just-10/', 'urlToImage': 'https://www.cnet.com/a/img/resize/35a6e3afee14157827729b6af5916ed99c3f1791/hub/2024/11/20/24ff18c9-9136-48ff-884f-ddb0e4c9ff7b/pikachu-ramen-bowl.png?auto=webp&fit=crop&height=675&width=1200', 'publishedAt': '2024-11-20T12:55:00Z', 'content': "We've been able to find some niche Black Friday deals that should make perfect gifts and help you knock out your holiday shopping on the cheap. If you've already gone through Black Friday Nintendo Sw… [+1231 chars]"}, {'source': {'id': None, 'name': 'Slashdot.org'}, 'author': 'msmash', 'title': 'Pokemon Go Players Have Unwittingly Trained AI To Navigate the World', 'description': 'Augmented reality gaming company Niantic plans to develop an AI system for navigating physical spaces using data from millions of unsuspecting players of its games "Pokemon Go" and "Ingress," the company announced in a blog post. The "Large Geospatial Model" …', 'url': 'https://slashdot.org/story/24/11/19/175239/pokemon-go-players-have-unwittingly-trained-ai-to-navigate-the-world', 'urlToImage': 'https://a.fsdn.com/sd/topics/ai_64.png', 'publishedAt': '2024-11-19T18:43:00Z', 'content': 'You\'re training it.I hope you get what you want, because, next year, "AI", with your intellectual property, will put you out of business.\r\nIt\'s a sleight of hand. Wow! Look over there, it\'s a herd of… [+130 chars]'}, {'source': {'id': 'business-insider', 'name': 'Business Insider'}, 'author': 'Jacob Shamsian,Jack Newsham,Katherine Long,Ana Altchek,Joi-Marie McKenzie,Sophie Kleeman', 'title': "What we know about Luigi Mangione, the former Ivy League grad arrested and linked to UnitedHealthcare CEO's killing", 'description': 'Luigi Mangione, identified as a person of interest in Brian Thompson killing, founded an app and reviewed The Unabomber Manifesto.', 'url': 'https://www.businessinsider.com/luigi-mangione-unitedhealth-ceo-killing-person-what-to-know-2024-12', 'urlToImage': 'https://i.insider.com/67575deb52dd0818d1a60c13?width=680&format=jpeg', 'publishedAt': '2024-12-09T22:37:09Z', 'content': "Luigi Mangioni's entry in the Gilman School class of 2016 yearbook.Anonymous\r\n<ul><li>Luigi Mangione has been arrested in an investigation into UnitedHealth CEO Brian Thompson's killing.</li><li>Mang… [+5088 chars]"}, {'source': {'id': None, 'name': 'VentureBeat'}, 'author': 'Dean Takahashi', 'title': 'Dino Ying stayed the course on esports and Black Myth: Wukong | interview', 'description': 'Dino Ying has been a patient leader. As chairman of Hero Esports (formerly VSPO) and Hero Games, he has had to endure a long period of investment.', 'url': 'https://venturebeat.com/games/dino-ying-stayed-the-course-on-esports-and-black-myth-wukong-i ...
# 200
# application/json; charset=utf-8
# utf-8

# %% [markdown]
# Le code d’état de la réponse HTTP est 200, ce qui signifie que la demande de l’URL a réussi.

# %%
r.json()
# Out:
# {'status': 'ok',
#  'totalResults': 967,
#  'articles': [{'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Jeremy Gan',
#    'title': 'The Chinese version of the Nintendo Switch won’t be able to access the eShop in 2026',
#    'description': 'If you didn’t know, Tencent (which is, among other things, the world’s biggest video game vendor) is the one that brought the Nintendo Switch to China\r\n in 2019. These Chinese versions of the console have access to fewer games, and they also can’t connect wit…',
#    'url': 'https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_abfc57ed-3dbc-4ccd-abe7-47f379542767',
#    'urlToImage': None,
#    'publishedAt': '2024-11-26T16:32:46Z',
#    'content': "If you click 'Accept all', we and our partners, including 237 who are part of the IAB Transparency &amp; Consent Framework, will also store and/or access information on a device (in other words, use … [+678 chars]"},
#   {'source': {'id': None, 'name': 'CNET'},
#    'author': 'Jason Coles',
#    'title': 'Give a Pokemon Fan Something They Don’t Have With This Pikachu Ramen Bowl for Just $10',
#    'description': "Grab this ceramic bowl while it's 58% off thanks to this Black Friday deal at Amazon.",
#    'url': 'https://www.cnet.com/deals/give-a-pokemon-fan-something-they-dont-have-with-this-pikachu-ramen-bowl-for-just-10/',
#    'urlToImage': 'https://www.cnet.com/a/img/resize/35a6e3afee14157827729b6af5916ed99c3f1791/hub/2024/11/20/24ff18c9-9136-48ff-884f-ddb0e4c9ff7b/pikachu-ramen-bowl.png?auto=webp&fit=crop&height=675&width=1200',
#    'publishedAt': '2024-11-20T12:55:00Z',
#    'content': "We've been able to find some niche Black Friday deals that should make perfect gifts and help you knock out your holiday shopping on the cheap. If you've already gone through Black Friday Nintendo Sw… [+1231 chars]"},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'msmash',
#    'title': 'Pokemon Go Players Have Unwittingly Trained AI To Navigate the World',
#    'description': 'Augmented reality gaming company Niantic plans to develop an AI system for navigating physical spaces using data from millions of unsuspecting players of its games "Pokemon Go" and "Ingress," the company announced in a blog post. The "Large Geospatial Model" …',
#    'url': 'https://slashdot.org/story/24/11/19/175239/pokemon-go-players-have-unwittingly-trained-ai-to-navigate-the-world',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/ai_64.png',
#    'publishedAt': '2024-11-19T18:43:00Z',
#    'content': 'You\'re training it.I hope you get what you want, because, next year, "AI", with your intellectual property, will put you out of business.\r\nIt\'s a sleight of hand. Wow! Look over there, it\'s a herd of… [+130 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Jacob Shamsian,Jack Newsham,Katherine Long,Ana Altchek,Joi-Marie McKenzie,Sophie Kleeman',
#    'title': "What we know about Luigi Mangione, the former Ivy League grad arrested and linked to UnitedHealthcare CEO's killing",
#    'description': 'Luigi Mangione, identified as a person of interest in Brian Thompson killing, founded an app and reviewed The Unabomber Manifesto.',
#    'url': 'https://www.businessinsider.com/luigi-mangione-unitedhealth-ceo-killing-person-what-to-know-2024-12',
#    'urlToImage': 'https://i.insider.com/67575deb52dd0818d1a60c13?width=680&format=jpeg',
#    'publishedAt': '2024-12-09T22:37:09Z',
#    'content': "Luigi Mangioni's entry in the Gilman School class of 2016 yearbook.Anonymous\r\n<ul><li>Luigi Mangione has been arrested in an investigation into UnitedHealth CEO Brian Thompson's killing.</li><li>Mang… [+5088 chars]"},
#   {'source': {'id': None, 'name': 'VentureBeat'},
#    'author': 'Dean Takahashi',
#    'title': 'Dino Ying stayed the course on esports and Black Myth: Wukong | interview',
#    'description': 'Dino Ying has been a patient leader. As chairman of Hero Esports (formerly VSPO) and Hero Games, he has had to endure a long period of investment.',
#    'url': 'https://venturebeat.com/games/dino-ying-stayed-the-course-on-esports-and-black-myth-wukong-interview/',
#    'urlToImage': 'https://venturebeat.com/wp-content/uploads/2024/08/Black-Myth-Wukong.jpg?w=1024?w=1200&strip=all',
#    'publishedAt': '2024-12-03T18:00:00Z',
#    'content': 'Dino Ying has been a patient leader. As chairman of Hero Esports (formerly VSPO) and Hero Games, he has had to endure a long period of investment before getting much hope of a payoff. Yet Hero Esport… [+15682 chars]'},
#   {'source': {'id': 'ign', 'name': 'IGN'},
#    'author': 'Eric Song',
#    'title': 'The Target Black Friday Sale Starts Now: The Best Deals on Pokemon TCG, Apple, Board Games, and More',
#    'description': 'One of the biggest and most anticipated Black Friday sales.',
#    'url': 'https://www.ign.com/articles/best-target-black-friday-sales',
#    'urlToImage': 'https://assets-prd.ignimgs.com/2024/11/28/targetbf3-1732797127320.jpg?width=1280',
#    'publishedAt': '2024-11-28T12:35:00Z',
#    'content': "The Target Black Friday Sale has officially commenced! Target is one of the most popular retailers for Black Friday, and one thing I've learned over the years of finding deals is that it knows how to… [+15217 chars]"},
#   {'source': {'id': 'ign', 'name': 'IGN'},
#    'author': 'Blythe Dujardin',
#    'title': '21 Nintendo Switch Games You Can Get for $30 or Less Right Now (Including Tears of the Kingdom)',
#    'description': "Tears of the Kingdom for $30? Personal 5 Royal for $15? These Switch deals definitely won't get better.",
#    'url': 'https://www.ign.com/articles/best-nintendo-switch-games-under-30-cyber-monday-2024',
#    'urlToImage': 'https://assets-prd.ignimgs.com/2024/12/01/zelda-1733093707537.jpg?width=1280',
#    'publishedAt': '2024-12-01T22:56:53Z',
#    'content': "Switch games aren't known for being cheap. Especially when it comes to first-party Nintendo titles like Zelda and Mario, you often see games sticking with an above $40 price tag years and years after… [+2485 chars]"},
#   {'source': {'id': 'ign', 'name': 'IGN'},
#    'author': 'Christian Wait',
#    'title': "These Are The Best Pokémon TCG Deals in Best Buy's Black Friday Sale",
#    'description': 'Pokémon TCG collections and trainer boxes are on sale for Black Friday, including Charizard ex Super-Premium, Paradox Wisdom, and Shrouded Fable ETB.',
#    'url': 'https://www.ign.com/articles/best-pokemon-tcg-deals-best-buy-black-friday-sale-2024',
#    'urlToImage': 'https://assets-prd.ignimgs.com/2024/07/30/pokemon-tcg-shrouded-fable-preview-ign-blogroll-art-3-1722335695218.png?width=1280',
#    'publishedAt': '2024-11-25T15:43:35Z',
#    'content': 'Prep your Pokémon TCG deck for epic battles and chase shiny cards for your collection. Black Friday is here to make your Pokémon dreams come true. These deals on premium Pokémon TCG boxes and ETBs ar… [+3557 chars]'},
#   {'source': {'id': 'ign', 'name': 'IGN'},
#    'author': 'Eric Song',
#    'title': 'This Microsoft Xbox 360 Building Kit From Target Is One of the Coolest Toys for Black Friday',
#    'description': 'This would make an incredible gift idea for any gaming fan who loves working on complex building block kits like LEGO. The MEGA Xbox 360 kit faithfully recreates this iconic console both inside and out.',
#    'url': 'https://www.ign.com/articles/mega-xbox-360-toy-set-at-target-black-friday-deal-2024',
#    'urlToImage': 'https://assets-prd.ignimgs.com/2024/11/24/megaxbox-1732486068915.jpg?width=1280',
#    'publishedAt': '2024-11-29T08:20:00Z',
#    'content': "Target has officially kicked off its Target Black Friday Sale, and one deal you might have missed is this really awesome MEGA Microsoft Xbox 360 Collector Building Set. It's normally $150 but there's… [+3401 chars]"},
#   {'source': {'id': None, 'name': 'Digital Trends'},
#    'author': 'Patrick Hearn',
#    'title': 'The Galaxy S25 could add a new feature perfect for mobile gaming',
#    'description': 'The Galaxy S25 could come with a new Game Assist mode that doubles the frame rate without affecting battery life or heat output.',
#    'url': 'https://www.digitaltrends.com/mobile/the-samsung-galaxy-s25-could-add-a-new-feature-perfect-for-mobile-gaming/',
#    'urlToImage': 'https://www.digitaltrends.com/wp-content/uploads/2024/04/samsung-galaxy-a35-game.jpg?resize=1200%2C630&p=1',
#    'publishedAt': '2024-11-18T15:35:11Z',
#    'content': 'The Samsung Galaxy S25 is set to blow fans away with its impressive specs, and the latest leak just lends more credence to those rumors. According to trusted leaker Jukanlosreve, Samsung is working o… [+1944 chars]'},
#   {'source': {'id': None, 'name': 'The New Yorker'},
#    'author': 'Kyle Chayka',
#    'title': 'The Fantasy of Cozy Tech',
#    'description': 'Kyle Chayka on the “cozy gaming” trend, evidenced in games like Stardew Valley, Vampire Therapist, and Wylde Flowers, which seeks to swath us in a digital and physical cocoon.',
#    'url': 'https://www.newyorker.com/culture/infinite-scroll/the-fantasy-of-cozy-tech',
#    'urlToImage': 'https://media.newyorker.com/photos/673d054aba3c33fac6abcac5/16:9/w_1280,c_limit/NewYorker_Cozycore_final.jpg',
#    'publishedAt': '2024-11-20T19:43:41Z',
#    'content': 'At a wide desk in a bedroom somewhere sits a figure, her back facing the camera, supported by an ergonomic white office chair. Her head is bracketed by puffy, white noise-cancelling headphones. Her w… [+13445 chars]'},
#   {'source': {'id': None, 'name': 'Android Police'},
#    'author': 'Stephen Radochia',
#    'title': 'In July I called this phone too expensive, Black Friday 2024 solves that',
#    'description': 'It started life at a rough price point, but the Moto Edge is finally where it belongs',
#    'url': 'https://www.androidpolice.com/i-didnt-love-the-moto-edge-2024-at-launch-but-i-adore-it-at-200-off/',
#    'urlToImage': 'https://static1.anpoimages.com/wordpress/wp-content/uploads/wm/2024/11/img_7508.jpg',
#    'publishedAt': '2024-11-29T14:57:10Z',
#    'content': 'When I reviewed the Moto Edge (2024), I highlighted how it was a tale of two phones. At $550, it didnt make sense; there were too many other mid-range phones offering more for less money. However, I … [+4676 chars]'},
#   {'source': {'id': None, 'name': 'Rock Paper Shotgun'},
#    'author': 'Edwin Evans-Thirlwell',
#    'title': "Kura5 is a free spiritual successor to Kojima's sun-loving Boktai vampire-hunting series",
#    'description': 'Long before Hideo Kojima made the first triple-A walking simulator, he was trying to spin sunlight into bullets. The game in question, Boktai: The Sun Is In Your Hand, is a Game Boy Advance title from 2003, in which you play a vampire-slaying gunslinger. The …',
#    'url': 'https://www.rockpapershotgun.com/kura5-is-a-free-spiritual-sequel-to-kojimas-sun-loving-boktai-vampire-hunting-series',
#    'urlToImage': 'https://assetsio.gnwcdn.com/1_is4Je64.png?width=1200&height=630&fit=crop&enable=upscale&auto=webp',
#    'publishedAt': '2024-11-22T12:25:07Z',
#    'content': 'Long before Hideo Kojima made the first triple-A walking simulator, he was trying to spin sunlight into bullets. The game in question, Boktai: The Sun Is In Your Hand, is a Game Boy Advance title fro… [+2002 chars]'},
#   {'source': {'id': None, 'name': 'Tim.blog'},
#    'author': 'Tim Ferriss',
#    'title': 'Cyan Banister — From Homeless and Broke to Top Angel Investor (Uber, SpaceX, and 100+ More) (#780)',
#    'description': 'Q&A with Tim Ferriss — How to Live with Urgency, Find Joy, and Fight Complacency\nThe post Cyan Banister — From Homeless and Broke to Top Angel Investor (Uber, SpaceX, and 100+ More) (#780) appeared first on The Blog of Author Tim Ferriss.',
#    'url': 'https://tim.blog/2024/11/28/cyan-banister/',
#    'urlToImage': 'https://149346886.v2.pressablecdn.com/wp-content/uploads/2024/11/Cyan-Illustration-scaled.jpg',
#    'publishedAt': '2024-11-28T19:40:46Z',
#    'content': 'Cyan Banister (@cyantist) is a general partner at Long Journey Ventures, an early-stage venture capital firm focused on early and new investments. Cyan was an early investor in Uber, SpaceX, DeepMind… [+16071 chars]'},
#   {'source': {'id': None, 'name': 'CNET'},
#    'author': 'Matt Poskitt',
#    'title': 'Huge Video Game Sale at Woot Slashes Prices on Popular Titles for PS5, Nintendo Switch and Xbox',
#    'description': "Save up to 75% on Mario, Marvel's Spider-Man, Pokemon, Splatoon, EA Sports FC, Silent Hill and many more top titles.",
#    'url': 'https://www.cnet.com/deals/huge-video-game-sale-at-woot-slashes-prices-on-popular-titles-for-ps5-nintendo-switch-and-xbox/',
#    'urlToImage': 'https://www.cnet.com/a/img/resize/9d60798298de105ae5545768ed6442ae1a7ef707/hub/2024/11/28/88de1b3a-869a-44f5-b772-148ee8985c9e/woot-video-game-deal.png?auto=webp&fit=crop&height=675&width=1200',
#    'publishedAt': '2024-11-28T15:47:00Z',
#    'content': "With holiday gifting on the agenda, we're seeing plenty of video game sales right now, but Woot's might be the best of the lot. As part of Black Friday, the Amazon-owned online retailer has put up hu… [+1958 chars]"},
#   {'source': {'id': None, 'name': 'CNET'},
#    'author': 'Zachary McAuliffe',
#    'title': 'PlayStation Plus Free December Games Include Aliens and More',
#    'description': 'All PS Plus subscribers can play these games from now until January.',
#    'url': 'https://www.cnet.com/tech/gaming/playstation-plus-free-december-games-include-aliens-and-more/',
#    'urlToImage': 'https://www.cnet.com/a/img/resize/04bccc22fb03ae7495e66c82d1a99ff9631c6814/hub/2024/11/26/8d5a5035-6518-4531-8808-ce472c80a931/6-2.png?auto=webp&fit=crop&height=675&width=1200',
#    'publishedAt': '2024-12-03T12:00:07Z',
#    'content': "PlayStation Plus is Sony's version of Xbox Game Pass, and it offers subscribers a large and constantly expanding library of games. There are three plans starting at $10 a month, but each plan gives s… [+1874 chars]"},
#   {'source': {'id': None, 'name': 'CNET'},
#    'author': 'Max McHone',
#    'title': 'Black Friday Nintendo Switch Deals: 45 Offers Across Hardware, Games and Accessories',
#    'description': 'Black Friday is bringing in huge deals on Nintendo Switch consoles, games, and gear. Shop these deals before they are gone',
#    'url': 'https://www.cnet.com/deals/best-black-friday-nintendo-switch-deals-2024-11-29/',
#    'urlToImage': 'https://www.cnet.com/a/img/resize/22051d0b5ba40bed827f7cfef03b5abdc67a992e/hub/2024/11/26/a56cf465-3573-4107-a1fe-5db890bd8e40/best-black-friday-nintendo-switch-deals.png?auto=webp&fit=crop&height=675&width=1200',
#    'publishedAt': '2024-11-29T10:19:05Z',
#    'content': "It's holiday shopping season, and if you need to pick up some Nintendo games, now is the time to do it. Black Friday offers dozens of discounts with anywhere between $10 to $30 being knocked off firs… [+5566 chars]"},
#   {'source': {'id': None, 'name': 'Windows Central'},
#    'author': 'jez@windowscentral.com (Jez Corden)',
#    'title': 'Microsoft Edge edged its way to a boosted 13% market share on ... Pornhub. Windows also increased its load, while Xbox saw a massive 70% drop, handing the job to PlayStation.',
#    'description': "Pornhub's all-important year in review reveals evolving browser habits, offering Microsoft's platform a mixed bag. Let's take a deeper dive. It's SFW, I promise.",
#    'url': 'https://www.windowscentral.com/microsoft/microsoft-edge-edged-its-way-to-a-boosted-12-percent-market-share-on-pornhub',
#    'urlToImage': 'https://cdn.mos.cms.futurecdn.net/bqjKhQjNf6dcJnnJXfm7e8-1200-80.jpg',
#    'publishedAt': '2024-12-12T00:10:46Z',
#    'content': '<ul><li>Adult entertainment site Pornhub just shared 2024 traffic stats.</li><li>Pornhub showed an increased share for Windows and Edge, but a decline for Xbox.</li><li>Microsoft franchises like Mine… [+5658 chars]'},
#   {'source': {'id': None, 'name': 'Journal du geek'},
#    'author': 'Arthur Nicolle',
#    'title': 'Pokémon TCG Pocket\xa0: comment obtenir vos boosters gratuits pour l’extension L’Île Fabuleuse',
#    'description': 'Pour fêter la sortie du bloc "L\'Île Fabuleuse", le jeu mobile vous offre de quoi ouvrir des cartes supplémentaires.',
#    'url': 'https://www.journaldugeek.com/2024/12/17/pokemon-tcg-pocket-comment-obtenir-vos-boosters-gratuits-pour-lextension-lile-fabuleuse/',
#    'urlToImage': 'https://www.journaldugeek.com/app/uploads/2024/12/pokemon-tcg-pocket-boosters-ile-fabuleuse.jpg',
#    'publishedAt': '2024-12-17T08:52:47Z',
#    'content': 'Ça y est\xa0: Pokémon JCC Pocket accueille enfin de nouvelles cartes. Depuis son lancement mondial le 30 octobre dernier, l’application de collection ne se reposait que sur une seule extension. Puissanc… [+2788 chars]'},
#   {'source': {'id': None, 'name': 'GameSpot'},
#    'author': 'Blair Marnell',
#    'title': 'Pokemon Gold And Silver Is Getting Some Awesome 25th Anniversary Merch',
#    'description': "Devoted fans of Pokemon should be well aware that 25 years ago this month, Pokemon Gold and Silver debuted in Japan before coming to the U.S. nearly a year later. The game added over 100 new Pokemon to the lore and it's widely regarded as one of the best titl…",
#    'url': 'https://www.gamespot.com/articles/pokemon-gold-and-silver-is-getting-some-awesome-25th-anniversary-merch/1100-6527809/',
#    'urlToImage': 'https://www.gamespot.com/a/uploads/screen_kubrick/1837/18375603/4400911-pokemonanniversarymerch.jpg',
#    'publishedAt': '2024-11-18T13:22:00Z',
#    'content': 'Devoted fans of Pokemon should be well aware that 25 years ago this month, Pokemon Gold and Silver debuted in Japan before coming to the U.S. nearly a year later. The game added over 100 new Pokemon … [+1753 chars]'},
#   {'source': {'id': None, 'name': 'GameSpot'},
#    'author': 'Steven Petite',
#    'title': "Official Pokemon Sprite Building Sets Are Only $17 In Target's Black Friday Sale",
#    'description': "If you love classic Pokemon games and pixel art, you might have trouble deciding which of Mega's officially licensed Pokemon buildable models to pick up during Target's Black Friday sale. All six of the awesome Pokemon Retro Sets are on sale for only $17.49 e…",
#    'url': 'https://www.gamespot.com/articles/official-pokemon-sprite-building-sets-are-only-17-in-targets-black-friday-sale/1100-6526933/',
#    'urlToImage': 'https://www.gamespot.com/a/uploads/screen_kubrick/1595/15950357/4379613-pokemonretrosets.png',
#    'publishedAt': '2024-11-29T05:02:00Z',
#    'content': "If you love classic Pokemon games and pixel art, you might have trouble deciding which of Mega's officially licensed Pokemon buildable models to pick up during Target's Black Friday sale. All six of … [+2867 chars]"},
#   {'source': {'id': None, 'name': 'GameSpot'},
#    'author': 'Eddie Makuch',
#    'title': 'Pokemon And Wallace & Gromit Studio Teaming Up For New Project Due In 2027',
#    'description': "Pokemon and Aardman are teaming up for... something. The two companies announced a partnership today, saying whatever they're making together is coming in 2027.A teaser image showed a Poke Ball forming with Aardman's trademark clay for its claymation animatio…",
#    'url': 'https://www.gamespot.com/articles/pokemon-and-wallace-gromit-studio-teaming-up-for-new-project-due-in-2027/1100-6528371/',
#    'urlToImage': 'https://www.gamespot.com/a/uploads/screen_kubrick/1179/11799911/4413771-screenshot2024-12-11at9.18.27am.png',
#    'publishedAt': '2024-12-11T14:06:00Z',
#    'content': "Pokemon and Aardman are teaming up for... something. The two companies announced a partnership today, saying whatever they're making together is coming in 2027.\r\nA teaser image showed a Poke Ball for… [+1282 chars]"},
#   {'source': {'id': None, 'name': 'GameSpot'},
#    'author': 'Steven Petite',
#    'title': 'Snap Up New Pokemon Snap For $25 At Best Buy Before It Sells Out',
#    'description': "Best Buy has a phenomenal deal on New Pokemon Snap for Nintendo Switch. The long-awaited sequel to the N64 classic is on sale for only $25. This $35 discount isn't likely to stick around for long. The same goes for Best Buy's Fire Emblem Engage $20 deal. See …",
#    'url': 'https://www.gamespot.com/articles/snap-up-new-pokemon-snap-for-25-at-best-buy-before-it-sells-out/1100-6505299/',
#    'urlToImage': 'https://www.gamespot.com/a/uploads/screen_kubrick/1601/16018044/4002688-pokemonsnap.jpg',
#    'publishedAt': '2024-12-05T17:20:00Z',
#    'content': "Best Buy has a phenomenal deal on New Pokemon Snap for Nintendo Switch. The long-awaited sequel to the N64 classic is on sale for only $25. This $35 discount isn't likely to stick around for long. Th… [+1194 chars]"},
#   {'source': {'id': None, 'name': 'GameSpot'},
#    'author': 'Steven Petite',
#    'title': 'Amazon Has The Pikachu Lite-Brite For Only $12 In Its Black Friday Sale',
#    'description': 'The officially licensed Pokemon Lite-Brite is discounted to only $11.87 at Amazon for Black Friday. The Pokemon Edition of the classic light-up art toy released last year with a price tag of $25. Amazon has offered multiple discounts in recent months, but thi…',
#    'url': 'https://www.gamespot.com/articles/amazon-has-the-pikachu-lite-brite-for-only-12-in-its-black-friday-sale/1100-6519149/',
#    'urlToImage': 'https://www.gamespot.com/a/uploads/screen_kubrick/1601/16018044/4220398-pokemon-brite.jpg',
#    'publishedAt': '2024-11-29T04:09:00Z',
#    'content': 'The officially licensed Pokemon Lite-Brite is discounted to only $11.87 at Amazon for Black Friday. The Pokemon Edition of the classic light-up art toy released last year with a price tag of $25. Ama… [+2019 chars]'},
#   {'source': {'id': None, 'name': 'GameSpot'},
#    'author': 'Kevin Knezevic',
#    'title': 'Pokemon Go December 2024 Events: Raids, Spotlight Hours, Community Day, And More',
#    'description': "Pokemon Go's newest season, Dual Destiny, has officially begun, and the game is ushering it in with a variety of events and new content this month. In addition to new raid bosses and Spotlight Hours, Pokemon Go will introduce a handful of new Pokemon to catch…",
#    'url': 'https://www.gamespot.com/articles/pokemon-go-december-2024-events-raids-spotlight-hours-community-day-and-more/1100-6528075/',
#    'urlToImage': 'https://www.gamespot.com/a/uploads/screen_kubrick/1578/15787979/4405959-6865313024-czxf-z1w-xUiP6qqCHcce8cUStE_MCNkK8qxOiY29lZS79kl4IJIjLySLe2i4NNfuJtIcB5w3swkGmImjNGMaXtygXGeoHQ3PH8XAI5uihTUtQ%3Dw1440-e365.jpg',
#    'publishedAt': '2024-12-01T20:00:00Z',
#    'content': "Pokemon Go's newest season, Dual Destiny, has officially begun, and the game is ushering it in with a variety of events and new content this month. In addition to new raid bosses and Spotlight Hours,… [+6018 chars]"},
#   {'source': {'id': None, 'name': 'GameSpot'},
#    'author': 'Jon Bitner',
#    'title': 'Tons Of Pokemon Blu-Rays And DVDs Are Discounted For Black Friday',
#    'description': 'Amazon is discounting a long list of Pokemon Blu-rays and DVDs for Black Friday, some of which are down to their best prices of the year. Surprisingly, not many Pokemon seasons have made the jump to Blu-ray, and you’ll notice that most of the offers are for s…',
#    'url': 'https://www.gamespot.com/articles/tons-of-pokemon-blu-rays-and-dvds-are-discounted-for-black-friday/1100-6527909/',
#    'urlToImage': 'https://www.gamespot.com/a/uploads/screen_kubrick/1701/17013431/4403121-pokemondeals.jpg',
#    'publishedAt': '2024-11-21T08:00:00Z',
#    'content': 'Amazon is discounting a long list of Pokemon Blu-rays and DVDs for Black Friday, some of which are down to their best prices of the year. Surprisingly, not many Pokemon seasons have made the jump to … [+1313 chars]'},
#   {'source': {'id': None, 'name': 'GameSpot'},
#    'author': 'Blair Marnell',
#    'title': 'Niantic Used Pokemon Go Players To Create Real-World AI Navigation Model',
#    'description': "For the past eight years, Pokemon Go players have helped make Niantic's game one of the top titles in mobile gaming. Apparently, players have also been helping Niantic create a 3D model of the world, which is being expanded via AI into a Large Geospatial Mode…",
#    'url': 'https://www.gamespot.com/articles/niantic-used-pokemon-go-players-to-create-real-world-ai-navigation-model/1100-6527871/',
#    'urlToImage': 'https://www.gamespot.com/a/uploads/screen_kubrick/1837/18375603/4402219-pokemongo.jpg',
#    'publishedAt': '2024-11-19T19:08:00Z',
#    'content': "For the past eight years, Pokemon Go players have helped make Niantic's game one of the top titles in mobile gaming. Apparently, players have also been helping Niantic create a 3D model of the world,… [+1948 chars]"},
#   {'source': {'id': None, 'name': 'GameSpot'},
#    'author': 'Jason Fanelli',
#    'title': 'Pokemon TCG Pocket Mythical Island Expansion Adds 80 Cards, Including One That Turns Off Evolutions',
#    'description': 'With over 60 million downloads reported so far, Pokemon TCG Pocket is proving to be another smash-hit mobile game for Pikachu and his thousands of Pokemon pals. Those 60 million people have only had one set to work with--until next week, when the first expans…',
#    'url': 'https://www.gamespot.com/articles/pokemon-tcg-pocket-mythical-island-expansion-adds-80-cards-including-one-that-turns-off-evolutions/1100-6528407/',
#    'urlToImage': 'https://www.gamespot.com/a/uploads/screen_kubrick/3/37852/4414515-mew.jpg',
#    'publishedAt': '2024-12-12T14:27:00Z',
#    'content': 'With over 60 million downloads reported so far, Pokemon TCG Pocket is proving to be another smash-hit mobile game for Pikachu and his thousands of Pokemon pals. Those 60 million people have only had … [+1578 chars]'},
#   {'source': {'id': None, 'name': 'GameSpot'},
#    'author': 'Darryn Bonthuys',
#    'title': 'These Impressive Poke Ball Replicas Are On Sale For Black Friday',
#    'description': "What do you get the Pokemon fan in your life who seemingly has everything? A Poke Ball, that's what. Amazon is offering several high-end, officially licensed replicas of this iconic piece of monster-catching equipment at a discount for Black Friday. The model…",
#    'url': 'https://www.gamespot.com/articles/these-impressive-poke-ball-replicas-are-on-sale-for-black-friday/1100-6528013/',
#    'urlToImage': 'https://www.gamespot.com/a/uploads/screen_kubrick/1601/16018044/4404898-pokeballs.jpg',
#    'publishedAt': '2024-11-24T15:20:00Z',
#    'content': "What do you get the Pokemon fan in your life who seemingly has everything? A Poke Ball, that's what. Amazon is offering several high-end, officially licensed replicas of this iconic piece of monster-… [+1127 chars]"},
#   {'source': {'id': None, 'name': 'GameSpot'},
#    'author': 'Blair Marnell',
#    'title': "Pokemon Go Developer Doesn't Want Its AI Mapping Data Used For War",
#    'description': "Pokemon Go players recently learned that the game's developer, Niantic, is using their data to create a 3D model of the world before expanding it into a Large Geospatial Model with AI. Niantic is hoping to monetize this data, but even at this early stage, the…",
#    'url': 'https://www.gamespot.com/articles/pokemon-go-developer-doesnt-want-its-ai-mapping-data-used-for-war/1100-6528057/',
#    'urlToImage': 'https://www.gamespot.com/a/uploads/screen_kubrick/1837/18375603/4405678-pokemongo.jpg',
#    'publishedAt': '2024-11-26T16:23:00Z',
#    'content': "Pokemon Go players recently learned that the game's developer, Niantic, is using their data to create a 3D model of the world before expanding it into a Large Geospatial Model with AI. Niantic is hop… [+1967 chars]"},
#   {'source': {'id': None, 'name': 'GameSpot'},
#    'author': 'Eddie Makuch',
#    'title': 'Nintendo Announces Entire Switch eShop, All Online Support Ending In China',
#    'description': "Nintendo has announced a major change for the Switch console in China: The eShop and Nintendo Switch Online services will close in early 2026. The move comes amid the Chinese government's implementation of a rule limiting children to one hour of online game t…",
#    'url': 'https://www.gamespot.com/articles/nintendo-announces-entire-switch-eshop-all-online-support-ending-in-china/1100-6528054/',
#    'urlToImage': 'https://www.gamespot.com/a/uploads/screen_kubrick/1179/11799911/4405730-screenshot2024-11-26at9.06.09am.png',
#    'publishedAt': '2024-11-26T15:42:00Z',
#    'content': "Nintendo has announced a major change for the Switch console in China: The eShop and Nintendo Switch Online services will close in early 2026. The move comes amid the Chinese government's implementat… [+1333 chars]"},
#   {'source': {'id': None, 'name': 'GameSpot'},
#    'author': 'Brendan Hesse',
#    'title': 'Save Up To 50% On Pokemon TCG Packs, Lego Sets, And Other Collectibles At Best Buy This Weekend',
#    'description': "Best Buy's Black Friday Sale may be over, but the retailer still has plenty of holiday deals to take advantage of, including a three-day Doorbuster sale that sees up to 50% off select toys, trading cards, and collectibles between December 6 and December 8. Th…",
#    'url': 'https://www.gamespot.com/gallery/save-up-to-50-on-pokemon-tcg-packs-lego-sets-and-other-collectibles-at-best-buy-this-weekend/2900-6033/',
#    'urlToImage': 'https://www.gamespot.com/a/uploads/screen_kubrick/1701/17013431/4411560-000.jpg',
#    'publishedAt': '2024-12-06T23:31:00Z',
#    'content': 'GameSpot may receive revenue from affiliate and advertising partnerships for sharing this content and from purchases through links.'},
#   {'source': {'id': None, 'name': 'GameSpot'},
#    'author': 'Steven Petite',
#    'title': "Get Fire Emblem Engage For Only $20 Before It's Gone",
#    'description': 'Fire Emblem Engage is on sale for an incredible price at Best Buy. While. supplies last, you can get the tactical RPG for only $20 (was $60). We expect this deal to sell out fast. Best Buy also has New Pokemon Snap for only $25. See at Best Buy Fire Emblem En…',
#    'url': 'https://www.gamespot.com/articles/get-fire-emblem-engage-for-only-20-before-its-gone/1100-6522722/',
#    'urlToImage': 'https://www.gamespot.com/a/uploads/screen_kubrick/1601/16018044/4289156-fire-emblem-engage.jpg',
#    'publishedAt': '2024-12-05T17:13:00Z',
#    'content': 'Fire Emblem Engage is on sale for an incredible price at Best Buy. While. supplies last, you can get the tactical RPG for only $20 (was $60). We expect this deal to sell out fast. Best Buy also has N… [+1087 chars]'},
#   {'source': {'id': None, 'name': 'GameSpot'},
#    'author': 'Steven Petite',
#    'title': "A Handheld History Is 50% Off At Amazon, And It's The Perfect Gift For Portable Gaming Enthusiasts",
#    'description': 'A Handheld History (Hardcover) \r\n $20 (was $40) \r\nSee at Amazon \r\nThe Console Chronicles (Hardcover) \r\n $32 (was $40) \r\nSee at Amazon \r\nJoysticks to Haptics \r\n $40 | Releases June 10, 2025 \r\nPreorder at Amazon \r\nA Handheld History, one of the best books about…',
#    'url': 'https://www.gamespot.com/articles/a-handheld-history-is-50-off-at-amazon-and-its-the-perfect-gift-for-portable-gaming-enthusiasts/1100-6527455/',
#    'urlToImage': 'https://www.gamespot.com/a/uploads/screen_kubrick/1701/17013431/4392801-lostincult.jpg',
#    'publishedAt': '2024-12-07T05:51:00Z',
#    'content': 'Throughout its 272 pages, A Handheld History takes a comprehensive look at the handheld market, featuring commentary and full-color images for dozens of handhelds released over the past four-plus dec… [+1715 chars]'},
#   {'source': {'id': None, 'name': 'GameSpot'},
#    'author': 'Steve Watts',
#    'title': "Get 153 Episodes Of Bluey For Only $22.49 During Amazon's Cyber Monday Sale",
#    'description': 'Bluey: Seasons 1 & 2 (DVD) \r\n $12.49 (was $25) \r\nSee at Amazon \r\n36-inch Bluey Plush \r\n $30 (was $50) \r\nSee at Walmart \r\nBluey is wonderful. You may have heard your friends talk about the wholesome and hilarious animated series on Disney Plus and thought, gee…',
#    'url': 'https://www.gamespot.com/articles/get-153-episodes-of-bluey-for-only-22-49-during-amazons-cyber-monday-sale/1100-6519262/',
#    'urlToImage': 'https://www.gamespot.com/a/uploads/screen_kubrick/1585/15855271/4222214-4041379-screenshot2022-09-27at12.28.27pm-1.png',
#    'publishedAt': '2024-12-02T07:45:00Z',
#    'content': 'Bluey is wonderful. You may have heard your friends talk about the wholesome and hilarious animated series on Disney Plus and thought, gee, I sure would like to own the misadventures of a tight-knit … [+872 chars]'},
#   {'source': {'id': None, 'name': 'GameSpot'},
#    'author': 'Steven Petite',
#    'title': 'Today Only: Super Mario RPG On Nintendo Switch Is 50% Off',
#    'description': "Super Mario RPG is on sale for only $30 at Best Buy, but this deal is scheduled to end tonight, December 6, at 10 PM PT. It's actually the third time this week Best Buy has dropped the price of the 2023 Switch remake of Mario's first role-playing adventure. E…",
#    'url': 'https://www.gamespot.com/articles/today-only-super-mario-rpg-on-nintendo-switch-is-50-off/1100-6522833/',
#    'urlToImage': 'https://www.gamespot.com/a/uploads/screen_kubrick/1601/16018044/4291509-super-mario-rpg.jpg',
#    'publishedAt': '2024-12-07T03:05:00Z',
#    'content': "Super Mario RPG is on sale for only $30 at Best Buy, but this deal is scheduled to end tonight, December 6, at 10 PM PT. It's actually the third time this week Best Buy has dropped the price of the 2… [+3225 chars]"},
#   {'source': {'id': None, 'name': 'GameSpot'},
#    'author': 'Steven Petite',
#    'title': 'Super Mario RPG Is Only $30 At Best Buy Today (December 12)',
#    'description': "Best Buy's 12 Days of Gaming holiday promotion has brought back one of last week's best video game deals. Super Mario RPG for Nintendo Switch is on sale for 50% off. Make sure to snag Super Mario RPG for $30 before the promotion expires tonight, December 12, …",
#    'url': 'https://www.gamespot.com/articles/super-mario-rpg-is-only-30-at-best-buy-today-december-12/1100-6522833/',
#    'urlToImage': 'https://www.gamespot.com/a/uploads/screen_kubrick/1601/16018044/4291509-super-mario-rpg.jpg',
#    'publishedAt': '2024-12-12T15:48:00Z',
#    'content': "Best Buy's 12 Days of Gaming holiday promotion has brought back one of last week's best video game deals. Super Mario RPG for Nintendo Switch is on sale for 50% off. Make sure to snag Super Mario RPG… [+3032 chars]"},
#   {'source': {'id': None, 'name': 'GameSpot'},
#    'author': 'Darryn Bonthuys',
#    'title': 'Amazon Prime Members Can Get 72 Free Games Right Now',
#    'description': 'Amazon offers a pretty great bundle of PC games every month through its Prime Gaming hub--which is included as part of a Prime subscription--but this month you can grab a staggering number of games for free. Some of the bonus freebies were added to celebrate …',
#    'url': 'https://www.gamespot.com/articles/amazon-prime-members-can-get-72-free-games-right-now/1100-6528365/',
#    'urlToImage': 'https://www.gamespot.com/a/uploads/screen_kubrick/1601/16018044/4413725-amazongames.jpg',
#    'publishedAt': '2024-12-11T21:08:00Z',
#    'content': 'Amazon offers a pretty great bundle of PC games every month through its Prime Gaming hub--which is included as part of a Prime subscription--but this month you can grab a staggering number of games f… [+5315 chars]'},
#   {'source': {'id': None, 'name': 'GameSpot'},
#    'author': 'Jon Bitner',
#    'title': 'The Pac Man Reboot Shadow Labyrinth Is Getting A Special Edition Packed With Collectibles',
#    'description': 'Bandai Namco is making a bold pivot for Pac-Man’s 45th anniversary next year with Shadow Labyrinth. Announced at The Game Awards, the new game is a wild reimagining of the iconic yellow puck. Instead of a family-friendly arcade game, Shadow Labyrinth is a muc…',
#    'url': 'https://www.gamespot.com/articles/the-pac-man-reboot-shadow-labyrinth-is-getting-a-special-edition-packed-with-collectibles/1100-6528469/',
#    'urlToImage': 'https://www.gamespot.com/a/uploads/screen_kubrick/1701/17013431/4415364-newshortcut.lnk.jpg',
#    'publishedAt': '2024-12-13T16:12:00Z',
#    'content': 'Bandai Namco is making a bold pivot for Pac-Mans 45th anniversary next year with Shadow Labyrinth. Announced at The Game Awards, the new game is a wild reimagining of the iconic yellow puck. Instead … [+855 chars]'},
#   {'source': {'id': None, 'name': 'GameSpot'},
#    'author': 'Jon Bitner',
#    'title': "Walmart's Black Friday Sale Is Now Live, Here Are The Best Discounts",
#    'description': 'Walmart is discounting a bit of everything for Black Friday this year, with big savings on everything from video games and controllers to Lego sets and laptops. Walmart+ members were given early access to all the deals, but now the offers are available to eve…',
#    'url': 'https://www.gamespot.com/gallery/walmarts-black-friday-sale-is-now-live-here-are-the-best-discounts/2900-5985/',
#    'urlToImage': 'https://www.gamespot.com/a/uploads/screen_kubrick/1701/17013431/4405532-walmartthumb.jpg',
#    'publishedAt': '2024-11-25T22:55:00Z',
#    'content': 'GameSpot may receive revenue from affiliate and advertising partnerships for sharing this content and from purchases through links.'},
#   {'source': {'id': None, 'name': 'GameSpot'},
#    'author': 'Steve Watts',
#    'title': 'Best Metroidvania Games To Explore In 2024',
#    'description': 'The best metroidvanias are games that provide massive maps to explore, obstacles to conquer, and progression systems with constant "eureka" moments during your journey. Metroidvanias are one of the more popular genres out there, and with the gap between new C…',
#    'url': 'https://www.gamespot.com/gallery/best-metroidvania-games/2900-4005/',
#    'urlToImage': 'https://www.gamespot.com/a/uploads/screen_kubrick/1585/15855271/4402616-metroidvanias.jpg',
#    'publishedAt': '2024-11-20T15:24:00Z',
#    'content': 'GameSpot may receive revenue from affiliate and advertising partnerships for sharing this content and from purchases through links.'},
#   {'source': {'id': None, 'name': 'GameSpot'},
#    'author': 'Brendan Hesse',
#    'title': 'Best Buy Black Friday Deals: Lego, Video Games, Controllers, Headsets, And More',
#    'description': "We're in the thick of the Black Friday shopping season, with numerous big events happening online, including a site-wide sale at Best Buy. Best Buy's Black Friday sale is stacked with big price cuts to video games, TVs, PC gaming hardware, and other electroni…",
#    'url': 'https://www.gamespot.com/gallery/best-buy-black-friday-deals-lego-video-games-controllers-headsets-and-more/2900-5986/',
#    'urlToImage': 'https://www.gamespot.com/a/uploads/screen_kubrick/1701/17013431/4406561-bestbuythumb.jpg',
#    'publishedAt': '2024-11-27T23:46:00Z',
#    'content': 'GameSpot may receive revenue from affiliate and advertising partnerships for sharing this content and from purchases through links.'},
#   {'source': {'id': None, 'name': 'Golem.de'},
#    'author': 'Mike Faust',
#    'title': 'Räumliche Intelligenz: Niantic trainiert KI mit Geodaten',
#    'description': 'Räumliches Verständnis ist laut Niantic die nächste Herausforderung für KI-Modelle. Die Rohdaten dafür liefern Spieler von Ingress und Pokemon-Go. (Niantic, KI)',
#    'url': 'https://www.golem.de/sonstiges/zustimmung/auswahl.html?from=https%3A%2F%2Fwww.golem.de%2Fnews%2Fraeumliche-intelligenz-niantic-trainiert-ki-mit-geodaten-2411-190976.html&referer=https%3A%2F%2Ft.co%2F6af94f598b',
#    'urlToImage': None,
#    'publishedAt': '2024-11-20T15:25:02Z',
#    'content': 'Besuchen Sie Golem.de wie gewohnt mit Werbung und Tracking,\r\n indem Sie der Nutzung aller Cookies zustimmen.\r\n Details zum Tracking finden Sie im Privacy Center.\r\nSkript wurde nicht geladen. Informat… [+607 chars]'},
#   {'source': {'id': None, 'name': 'Xataka Android'},
#    'author': 'Eduardo Marín',
#    'title': 'Los stickers de WhatsApp van a cambiar para mejor. Así es la novedad que va a llegar a la aplicación, más stickers y más rápido',
#    'description': 'Si eres una de esas personas que constantemente envía stickers en sus chats de WhatsApp, y los colecciona como si fueran tesoros, esta novedad de WhatsApp es para ti. La plataforma está trabajando en un cambio importante para los stickers, uno que permitirá c…',
#    'url': 'https://www.xatakandroid.com/comunicacion-y-mensajeria/stickers-whatsapp-van-a-cambiar-para-mejor-asi-novedad-que-va-a-llegar-a-aplicacion-stickers-rapido',
#    'urlToImage': 'https://i.blogs.es/2af793/whatsapp-stickers-pack/840_560.jpeg',
#    'publishedAt': '2024-11-27T00:59:24Z',
#    'content': 'Si eres una de esas personas que constantemente envía stickers en sus chats de WhatsApp, y los colecciona como si fueran tesoros, esta novedad de WhatsApp es para ti. La plataforma está trabajando en… [+2226 chars]'},
#   {'source': {'id': None, 'name': 'Android Authority'},
#    'author': 'Ryan McNeal',
#    'title': 'Pokémon Go trainers have actually been helping train AI, too',
#    'description': "Niantic, the team behind Pokemon Go, is working on a new type of AI model that's training on data from its apps.",
#    'url': 'https://www.androidauthority.com/niantic-ai-pokemon-go-data-3501531/',
#    'urlToImage': 'https://www.androidauthority.com/wp-content/uploads/2019/09/Pokemon-Go-Character-Screen-1.jpg',
#    'publishedAt': '2024-11-20T18:11:17Z',
#    'content': '<ul><li>Niantic is building a new type of AI model that can understand and navigate the physical world.</li><li>The company is training its AI on data gathered from its mobile apps, like Pokemon Go a… [+3670 chars]'},
#   {'source': {'id': None, 'name': 'Android Authority'},
#    'author': 'Ryan Haines',
#    'title': 'Google vs Apple vs Samsung: Who has the best AI image generator?',
#    'description': "Using AI to make images is so hot right now. Here's how the solutions from Apple, Google, and Samsung stack up.",
#    'url': 'https://www.androidauthority.com/google-pixel-studio-vs-apple-image-playground-vs-samsung-portrait-studio-3502073/',
#    'urlToImage': 'https://www.androidauthority.com/wp-content/uploads/2024/08/Google-Pixel-9-Pro-XL-pixel-studio-interface.jpg',
#    'publishedAt': '2024-11-27T15:00:46Z',
#    'content': 'Despite their differences, Google, Apple, and Samsung often feel like three sides of the same weird, triangular coin. I mean, theyve all decided on pretty much the same set of AI-powered features for… [+12569 chars]'},
#   {'source': {'id': None, 'name': 'Android Authority'},
#    'author': 'Ryan Haines',
#    'title': 'These are my 5 favorite Android productivity features',
#    'description': 'Staying on top of work can be easier said than done, which is why I have several Android productivity features I rely on.',
#    'url': 'https://www.androidauthority.com/best-android-productivity-features-3504855/',
#    'urlToImage': 'https://www.androidauthority.com/wp-content/uploads/2024/08/Google-Pixel-9-Pro-in-a-mans-left-hand-as-he-uses-it-to-talk-on-the-phone.jpg',
#    'publishedAt': '2024-12-04T15:00:16Z',
#    'content': 'As a smartphone reviewer, a good chunk of my day involves being on my phone. After all, how can I find what I like and dislike about the eighth or ninth budget Android phone of the year without activ… [+7424 chars]'},
#   {'source': {'id': None, 'name': 'HYPEBEAST'},
#    'author': 'info@hypebeast.com (Hypebeast)',
#    'title': 'Pokémon TV Relaunches YouTube Channel',
#    'description': "It's time to watch 'em all as Pokémon drops its most classic and nostalgic episodes on YouTube. Pokémon TV has officially relaunched its YouTube channel, giving fans a chance to take a trip down memory lane. Bringing back the nostalgic episodes of the anime, …",
#    'url': 'https://hypebeast.com/2024/12/pokemon-tv-relaunches-youtube-channel-news',
#    'urlToImage': 'https://image-cdn.hypb.st/https%3A%2F%2Fhypebeast.com%2Fimage%2F2024%2F12%2F10%2Fpokemon-tv-relaunches-youtube-channel-news-tw2.jpg?w=1080&cbr=1&q=90&fit=max',
#    'publishedAt': '2024-12-11T08:18:34Z',
#    'content': 'It’s time to watch ‘em all as Pokémon drops its most classic and nostalgic episodes on YouTube. Pokémon TV has officially relaunched its YouTube channel, giving fans a chance to take a trip down memo… [+1581 chars]'},
#   {'source': {'id': None, 'name': 'Cracked.com'},
#    'author': 'Jesse',
#    'title': '14 Riveting World Records from the Riveting World of Chess',
#    'description': 'At the end of the day, chess is just analog Pokemon',
#    'url': 'https://www.cracked.com/article_44474_14-riveting-world-records-from-the-riveting-world-of-chess.html',
#    'urlToImage': 'https://s3.crackedcdn.com/phpimages/article/4/1/1/1190411.jpg',
#    'publishedAt': '2024-12-02T16:00:00Z',
#    'content': 'Youre 37 years old. Youve studied and battled for a lifetime, and youre at the top of your game the top of\xa0the game. Then an eight-year-old shows up and mops the floor with you.\r\nSeveral matches have… [+3630 chars]'},
#   {'source': {'id': None, 'name': 'Techdirt'},
#    'author': 'Dark Helmet',
#    'title': 'Nintendo, Palworld, A GTA 5 Mod, And An Injunction For The Japanese Market',
#    'description': 'We’re waiting for the lawsuit in Japan between Nintendo, The Pokémon Co., and Pocketpair, the developers of the hit game Palworld to really get going. In the meantime, the public commentary is filling the information void, including commentary from IP experts…',
#    'url': 'https://www.techdirt.com/2024/11/27/nintendo-palworld-a-gta-5-mod-and-an-injunction-for-the-japanese-market/',
#    'urlToImage': 'https://www.techdirt.com/wp-content/themes/techdirt/assets/images/td-rect-logo-white.png',
#    'publishedAt': '2024-11-28T03:39:00Z',
#    'content': 'from the uh-oh dept\r\nWe’re waiting for the lawsuit in Japan between Nintendo, The Pokémon Co., and Pocketpair, the developers of the hit game Palworld to really get going. In the meantime, the public… [+4339 chars]'},
#   {'source': {'id': None, 'name': '/FILM'},
#    'author': 'staff@slashfilm.com (Rafael Motamayor)',
#    'title': 'A Mysterious New Pokemon Project Is Coming From A Beloved Animation Studio',
#    'description': 'A brand-new Pokémon project is now officially being developed by one of the most critically-acclaimed animation studios to ever do it.',
#    'url': 'https://www.slashfilm.com/1735184/pokemon-project-animation-studio-aardman/',
#    'urlToImage': 'https://www.slashfilm.com/img/gallery/a-mysterious-new-pokemon-project-is-coming-from-a-beloved-animation-studio/l-intro-1733931999.jpg',
#    'publishedAt': '2024-12-11T15:49:22Z',
#    'content': 'This is the greatest stop-motion news since that time Aardman made an "Over the Garden Wall" short not to mention that time\xa0Aardman made a "Star Wars: Visions" short. Indeed, the famed "Wallace &amp;… [+1386 chars]'},
#   {'source': {'id': None, 'name': 'Frandroid'},
#    'author': 'William Zimmer',
#    'title': 'Le Galaxy S25 pourrait devenir un véritable smartphone gaming grâce à cette nouveauté',
#    'description': 'Samsung se préparerait à faire du Galaxy S25 un excellent smartphone pour le jeu vidéo grâce à une nouvelle fonctionnalité. De quoi révolutionner le gaming sur mobile\xa0? Peut-être bien.',
#    'url': 'https://www.frandroid.com/marques/samsung/2407634_le-galaxy-s25-pourrait-devenir-un-veritable-smartphone-gaming-grace-a-cette-nouveaute',
#    'urlToImage': 'https://images.frandroid.com/wp-content/uploads/2024/02/samsung-galaxy-s24-plus-7-1-scaled.jpg',
#    'publishedAt': '2024-11-19T15:19:06Z',
#    'content': 'Samsung se préparerait à faire du Galaxy S25 un excellent smartphone pour le jeu vidéo grâce à une nouvelle fonctionnalité. De quoi révolutionner le gaming sur mobile\xa0? Peut-être bien.\r\nSource : Chlo… [+2475 chars]'},
#   {'source': {'id': None, 'name': 'Frandroid'},
#    'author': 'Maxence Glineur',
#    'title': 'Google veut vous aider dans vos parties de jeux vidéo grâce à Gemini',
#    'description': "Avec Gemini 2.0, Google entrevoit la possibilité de créer une myriade d'agents multimodaux, capables de nous assister dans différentes situations. Et pour illustrer cette nouvelle « ère » de l'IA, quoi de mieux que le jeu vidéo ?",
#    'url': 'https://www.frandroid.com/culture-tech/intelligence-artificielle/google-gemini/2438886_google-veut-vous-aider-dans-vos-parties-de-jeux-video-grace-a-gemini',
# ...
#    'publishedAt': '2024-12-11T14:35:10Z',
#    'content': 'The Pokémon Company International and stop-motion studio Aardman have revealed they’re working on a “special project” together.\r\nFew details were revealed bar the project will land in 2027 and that “… [+1725 chars]'},
#   {'source': {'id': None, 'name': 'Tomshw.it'},
#    'author': 'Giulia Serena',
#    'title': 'Pokémon TCG Pocket: clessidre in omaggio per celebrare la nuova espansione, ecco come riscattarle',
#    'description': "The Pokemon Company ha lanciato una campagna promozionale per Pokémon TCG Pocket, offrendo clessidre gratuite ai giocatori che effettuano l'accesso dal 17 al 19 dicembre 2024 per celebrare le f...",
#    'url': 'https://www.tomshw.it/videogioco/pokemon-tcg-pocket-clessidre-in-omaggio-per-celebrare-la-nuova-espansione-ecco-come-riscattarle-2024-12-16',
#    'urlToImage': 'https://www.tomshw.it/storage/media/2024/10/39523/Pokémon-tcg-cover.jpg',
#    'publishedAt': '2024-12-16T09:58:32Z',
#    'content': "The Pokemon Company ha lanciato una campagna promozionale per Pokémon TCG Pocket, offrendo clessidre gratuite ai giocatori che effettuano l'accesso dal 17 al 19 dicembre 2024 per celebrare le festivi… [+1576 chars]"},
#   {'source': {'id': None, 'name': 'Tomshw.it'},
#    'author': 'Giulia Serena',
#    'title': 'Vorreste avere tutte le carte di Pokémon TCG Poket? In questo sito per lo meno le potete ammirare',
#    'description': 'Un fan appassionato ha creato un sito web che cataloga oltre 23.000 carte del Gioco di Carte Collezionabili Pokémon, offrendo una risorsa completa per gli appassionati e i collezionisti che des...',
#    'url': 'https://www.tomshw.it/videogioco/sito-web-mostra-larte-delle-carte-pokemon-tcg-2024-11-18',
#    'urlToImage': 'https://www.tomshw.it/storage/media/2024/11/41397/carte-pokemon-(1).png',
#    'publishedAt': '2024-11-18T13:54:24Z',
#    'content': 'Un fan appassionato ha creato un sito web che cataloga oltre 23.000 carte del\xa0Gioco di Carte Collezionabili Pokémon, offrendo una risorsa completa per gli appassionati e i collezionisti che desiderer… [+2924 chars]'},
#   {'source': {'id': None, 'name': 'Labaq.com'},
#    'author': 'zeronpa',
#    'title': 'アメリカ人「ITの専門家だけど、特定の文字を打ちたいときはこれをやっている…」あまり洗練されてない手法',
#    'description': 'IT系の人がみんな、デジタルまわりの行動がすべて洗練されているとは限りません。\nあるアルファベットの打ち方をしている博士号の人の発言がありました。',
#    'url': 'http://labaq.com/archives/51961390.html',
#    'urlToImage': 'https://livedoor.blogimg.jp/laba_q/imgs/4/e/4e9316c8-s.jpg',
#    'publishedAt': '2024-11-30T07:18:00Z',
#    'content': 'Reddit/PocketfulofThoughts\r\nWindowsPCe"Beyonce"Wikipedia\r\nWikipedia\r\nE - Wikipedia\r\n"Beyonce""Pokemon"\r\ne\r\niPhoneeWindowsOCR\r\nPC\r\nWindows\r\n"Pokemon"\r\n\'eWindowse\r\nUS Internationalccc'},
#   {'source': {'id': None, 'name': 'Himasoku.com'},
#    'author': 'himasoku123',
#    'title': '【悲報】パルワールドさん、任天堂との訴訟に関わるモンスター召喚のアクションを変更していたｗｗｗｗｗｗｗｗ',
#    'description': '1: 名無しさん必死だな 警備員[Lv.24] 2024/12/11(水) 19:13:59.23 ID:RcfF+Cun0\n 『パルワールド』がモンスター召喚のアクションを変更。任天堂との訴訟に関わる部分https://gadget.phileweb.com/post-90402/ \n\n7: 名無しさん必死だな 警備員[Lv.5] 2024/12/...',
#    'url': 'http://himasoku.com/archives/52272071.html',
#    'urlToImage': 'https://livedoor.blogimg.jp/himasoku123/imgs/8/3/83c0144c-s.jpg',
#    'publishedAt': '2024-12-12T04:25:40Z',
#    'content': 'BOTW\r\n17: [Lv.19] 2024/12/11() 19:35:50.11 ID:VRPagIhw0\r\n18: [Lv.1][] 2024/12/11() 19:35:54.62 ID:Ud3jsC6F0\r\n21: [Lv.20][] 2024/12/11() 19:39:02.98 ID:774NfMUu0\r\n23: [Lv.5][] 2024/12/11() 19:40:12.49… [+814 chars]'},
#   {'source': {'id': 'marca', 'name': 'Marca'},
#    'author': 'marca.com',
#    'title': "Los mejores chollos antes del Black Friday 2024 en Amazon: un vaquero Levi's al 56%, el videojuego EA SPORTS FC 25 con descuentazo...",
#    'description': 'Quedan horas para que se celebre la Semana de Black Friday en Amazon. Un evento que se prolongará del 21 de noviembre al 2 de diciembre con un carrusel de ofertas que promete ofert',
#    'url': 'https://www.marca.com/regalos-promociones/2024/11/20/673db5fae2704ebd3c8b457a.html',
#    'urlToImage': 'https://phantom-marca.unidadeditorial.es/5fd13126e51e3c9ee1484ef3c441315f/resize/1200/f/webp/assets/multimedia/imagenes/2024/11/20/17320973631776.png',
#    'publishedAt': '2024-11-20T10:12:45Z',
#    'content': 'Quedan horas para que se celebre la Semana de Black Friday en Amazon. Un evento que se prolongará del 21 de noviembre al 2 de diciembre con un carrusel de ofertas que promete ofertas increíbles en mo… [+49667 chars]'},
#   {'source': {'id': None, 'name': 'Tomshw.it'},
#    'author': 'Giulia Serena',
#    'title': 'Pokemon TCG Pocket: come sbloccare tutte le missioni segrete',
#    'description': 'Nel popolare gioco di carte collezionabili Pokémon TCG Pocket sono presenti diversi set di missioni segrete. Queste sfide nascoste offrono ricompense esclusive ai giocatori che riescono a compl...',
#    'url': 'https://www.tomshw.it/videogioco/pokemon-tcg-pocket-come-sbloccare-tutte-le-missioni-segrete-2024-12-02',
#    'urlToImage': 'https://www.tomshw.it/storage/media/2024/10/39523/Pokémon-tcg-cover.jpg',
#    'publishedAt': '2024-12-02T08:58:29Z',
#    'content': 'Nel popolare gioco di carte collezionabili Pokémon TCG Pocket sono presenti diversi set di missioni segrete. Queste sfide nascoste offrono ricompense esclusive ai giocatori che riescono a completarle… [+3519 chars]'},
#   {'source': {'id': None, 'name': 'Tomshw.it'},
#    'author': 'Andrea Maiellano',
#    'title': 'The Game Awards 2024: ecco tutte le nomination',
#    'description': "IN AGGIORNAMENTO\nSono finalmente state svelate tutte le nomination per i The Game Awards 2024, l'evento annuale che premia le migliori produzioni videoludiche dei vari generi oltre a decretare il gio...",
#    'url': 'https://www.tomshw.it/videogioco/i-candidati-ai-game-awards-2024-svelati-2024-11-18',
#    'urlToImage': 'https://www.tomshw.it/storage/media/2023/11/4097/TGA-2023.webp',
#    'publishedAt': '2024-11-18T17:40:24Z',
#    'content': "Sono finalmente state svelate tutte le nomination per i The Game Awards 2024, l'evento annuale che premia le migliori produzioni videoludiche dei vari generi oltre a decretare il gioco dell'anno. Le … [+5283 chars]"},
#   {'source': {'id': None, 'name': 'Techbang.com'},
#    'author': 'KKJ',
#    'title': '2024年最弱密碼年度榜單公布， 這些是你絕對不應該用的密碼',
#    'description': '2024年最弱密碼年度榜單 這些是您絕對不應該使用的\n密碼管理器 NordPass 再次發佈了全球最流行密碼的年度榜單--123456"連續第二年成為最常用的密碼。\n在 NordPass 編制的六次榜單中，同樣的數字有五次位居榜首，只是在 2022 年被著名的"password"所取代。 但是，一旦你撇開所有的 QWERTY、ABC 和 123，我們就能洞察到人類在建立保護自己最隱私資訊的文字時所考慮的問題。\n\n有人選擇"iloveyou"，也有人選擇"fXXkyou"。 還有一些人有獨特的興趣愛好，比如"pok…',
#    'url': 'https://www.techbang.com/posts/119604-the-annual-list-of-the-weakest-passwords-in-2024-is-announced',
#    'urlToImage': 'https://cdn2.techbang.com/system/excerpt_images/119604/original/245945253a4d6ea3f9d30730c8a6fa38.jpg?1731573339',
#    'publishedAt': '2024-11-25T00:30:00Z',
#    'content': 'NordPass --123456"\r\n NordPass 2022 "password" QWERTYABC 123\r\n"iloveyou""fXXkyou" "pokemon""naruto""samsung""Minecraft" "michelle""ashley""P@ssw0rd"\r\n "liverpool""lizottes""Flamingos Live" "salasana""… [+130 chars]'},
#   {'source': {'id': None, 'name': 'Digiday'},
#    'author': 'Marty Swant',
#    'title': 'AI Briefing: Inside Accenture and Nvidia’s plan to scale AI agents for enterprise business',
#    'description': 'Accenture and Nvidia execs explain how they hope to build and scale generative AI tools for marketing and other business functions.',
#    'url': 'http://digiday.com/media/ai-briefing-inside-accenture-and-nvidias-plan-to-scale-ai-agents-for-enterprise-business/',
#    'urlToImage': 'https://digiday.com/wp-content/uploads/sites/3/2024/10/ai-transition-digiday.gif',
#    'publishedAt': '2024-11-25T05:01:00Z',
#    'content': 'As Accenture and Nvidia seek to accelerate enterprise adoption of AI, their first proving ground has been closer to home: the consulting giant’s own marketing department.Last month, the companies ann… [+8062 chars]'},
#   {'source': {'id': 'marca', 'name': 'Marca'},
#    'author': 'marca.com',
#    'title': 'Los mejores chollos del día en Amazon: una batería externa al 81%, una chaqueta Columbia con descuentazo, una pulsera inteligente al 71%...',
#    'description': 'Quedan pocos días para que se celebre el Black Friday en Amazon. La Semana de Black Friday en Amazon se prolongará del 21 de noviembre al 2 de diciembre con un carrusel de ofertas',
#    'url': 'https://www.marca.com/regalos-promociones/2024/11/18/673b03c9268e3e381d8b4589.html',
#    'urlToImage': 'https://phantom-marca.unidadeditorial.es/4b94b333309170acbbffb2781e84dc6b/resize/1200/f/webp/assets/multimedia/imagenes/2024/11/18/17319206511099.png',
#    'publishedAt': '2024-11-18T09:08:18Z',
#    'content': 'Quedan pocos días para que se celebre el Black Friday en Amazon. La Semana de Black Friday en Amazon se prolongará del 21 de noviembre al 2 de diciembre con un carrusel de ofertas que promete ofertas… [+47124 chars]'},
#   {'source': {'id': None, 'name': 'Ascii.jp'},
#    'author': 'ASCII',
#    'title': '「ポケモンユナイト」にデカヌチャン参戦！ 好きなポケモンのライセンスがもらえるログインキャンペーンも',
#    'description': 'ポケモンはNintendo Switch／スマートフォン用ゲーム『Pokemon UNITE（ポケモンユナイト）』にて、ホリデーイベントを開催中。本日より新ポケモン「デカヌチャン」が参戦した。',
#    'url': 'https://weekly.ascii.jp/elem/000/004/240/4240622/',
#    'urlToImage': 'https://ascii.jp/img/2024/12/12/4132246/l/0034090ce8181b40.jpg',
#    'publishedAt': '2024-12-12T07:15:00Z',
#    'content': '1212Nintendo SwitchPokemon UNITE\r\n20241231\r\nhttps://www.pokemonunite.jp/ja/news/293/\r\n\xa0\r\nPokémon UNITE\r\nTiMi Studio Group, a subsidiary of Tencent GamesNintendo SwitchiOSAndroid\r\nNintendo Switch20217… [+133 chars]'},
#   {'source': {'id': 'ign', 'name': 'IGN'},
#    'author': 'Eric Song',
#    'title': 'Pokémon Plushies Are Over 50% Off for the Holidays: This Walmart Black Friday Deal is Back',
#    'description': "Catch em all at this price before they're gone.",
#    'url': 'https://www.ign.com/articles/pokmon-plushies-on-sale-at-walmart-holiday-deal-2024',
#    'urlToImage': 'https://assets-prd.ignimgs.com/2024/12/06/pokemonplushies-1733513282618.jpg?width=1280',
#    'publishedAt': '2024-12-06T19:40:00Z',
#    'content': "One of the most popular deals during Walmart's Black Friday Sale was 50% off Pokemon plushies. This deal sold out super quickly and did not return for Cyber Monday. Fortunately, they're back today al… [+1456 chars]"},
#   {'source': {'id': 'ign', 'name': 'IGN'},
#    'author': 'Christian Wait',
#    'title': "Pokémon Trading Cards Striker Tins Get Huge Discount in Walmart's Black Friday Sale",
#    'description': 'Pokémon TCG V Strikers Tins featuring Tyranitar V and Empoleon V are on sale for just $15 each at Walmart for Black Friday.',
#    'url': 'https://www.ign.com/articles/pokemon-tcg-tins-walmart-black-friday-sale-2024',
#    'urlToImage': 'https://assets-prd.ignimgs.com/2024/11/25/walmart-slashes-price-on-pokmon-tcg-strikers-tins-for-black-friday-ign-1732549002517.png?width=1280',
#    'publishedAt': '2024-11-25T17:00:00Z',
#    'content': "Calling all Pokémon Trainers and collectors: Walmart's Black Friday sale(Nov. 25: live at 12pm ET for Walmart+ members, and 5pm ET for everyone) has two Pokémon TCG V Strikers Tins on a budget-friend… [+3534 chars]"},
#   {'source': {'id': 'ign', 'name': 'IGN'},
#    'author': 'Christian Wait',
#    'title': 'Last Chance Cyber Monday Deals On Japanese Pokémon TCG Booster Boxes',
#    'description': 'Score the Japanese Pokémon TCG Scarlet & Violet 151 Booster Box for $99.99 (save $106) or grab other popular sets like Paradise Dragona and Super Electric Breaker for less as of Dec. 2.',
#    'url': 'https://www.ign.com/articles/pokemon-tcg-booster-boxes-japanese-cyber-monday-deals-2024',
#    'urlToImage': 'https://assets-prd.ignimgs.com/2024/12/02/untitled-design-90-1733141349480.png?width=1280',
#    'publishedAt': '2024-12-02T12:15:51Z',
#    'content': "Japanese Pokémon cards can be a rarity in the West, especially for Cyber Monday where sales are usually focused on English Pokémon TCG cards. Walmart's Cyber Monday sale has trainers covered, with de… [+1932 chars]"},
#   {'source': {'id': 'ign', 'name': 'IGN'},
#    'author': 'Robert Anderson',
#    'title': 'New Pokémon Funko Pop! Up for Preorder at Amazon, Includes Gengar, Zorua, and Fuecoco',
#    'description': None,
#    'url': 'https://www.ign.com/articles/funko-pop-pokemon-preorder-new-amazon-gengar-zorua-and-fuecoco',
#    'urlToImage': 'https://assets-prd.ignimgs.com/2024/12/10/new-pokemon-funko-up-for-preorder-ign-2024-gengar-1733841407357.png?width=1280',
#    'publishedAt': '2024-12-10T14:52:20Z',
#    'content': "Amazon has listed three brand-new Pokémon Funko Pop! figures, and they're available to preorder from today. Each of the vinyl figures is between 3.4-3.7 inches tall, costs $12.99, and will be release… [+1836 chars]"},
#   {'source': {'id': 'ign', 'name': 'IGN'},
#    'author': 'Christian Wait',
#    'title': 'I Love Ultrawide Gaming Monitors, But These UK Deals Are Next Level',
#    'description': 'As of Dec. 7, ultrawide gaming monitors like the ASUS TUF Gaming VG34VQEL1A are on sale for up to 38% off in the UK. Prices start at £248.99.',
#    'url': 'https://www.ign.com/articles/i-love-ultrawide-gaming-monitors-but-these-uk-deals-are-next-level',
#    'urlToImage': 'https://assets-prd.ignimgs.com/2024/12/07/airpods-max-hero-22-1733569128241.png?width=1280',
#    'publishedAt': '2024-12-07T11:03:38Z',
#    'content': 'Imagine an Orc from Space Marine I accent rocking up and being like, "Oi mate, listen. Why don\'t I come round there and give you a massive screen so you damn splat that bloody Space Marine before any… [+3645 chars]'},
#   {'source': {'id': 'ign', 'name': 'IGN'},
#    'author': 'Eric Song',
#    'title': 'Target Has the Coolest Black Friday Toy Deal for Gamers',
#    'description': 'This would make an incredible gift idea for any gaming fan who loves working on complex building block kits like LEGO. The MEGA Xbox 360 kit faithfully recreates this iconic console both inside and out.',
#    'url': 'https://www.ign.com/articles/mega-xbox-360-toy-set-black-friday-deal-2024',
#    'urlToImage': 'https://assets-prd.ignimgs.com/2024/11/24/megaxbox-1732486068915.jpg?width=1280',
#    'publishedAt': '2024-11-24T22:40:00Z',
#    'content': "Target just recently kicked off its official Target Black Friday Sale, and one deal you might have missed is this really awesome MEGA Microsoft Xbox 360 Collector Building Set. It's normally $150 but… [+3214 chars]"},
#   {'source': {'id': 'ign', 'name': 'IGN'},
#    'author': 'Christian Wait',
#    'title': 'PS5 DualSense UK Cyber Monday Deals Are Back For A Limited Time',
#    'description': 'Cyber Monday PS5 deals are back: Save up to 39% on DualSense controllers, including the Edge and Cosmic Red editions. Don’t miss out, as these savings won’t last!',
#    'url': 'https://www.ign.com/articles/ps5-dualsense-uk-cyber-monday-deals-are-back-for-a-limited-time',
#    'urlToImage': 'https://assets-prd.ignimgs.com/2024/12/05/airpods-max-hero-16-1733395908315.png?width=1280',
#    'publishedAt': '2024-12-05T10:52:42Z',
#    'content': 'UK Cyber Monday has come and gone, but some of the best PS5 DualSense deals are making a surprise return. Grab the DualSense Edge for £179.97 (14% off), or snag other editions like Cosmic Red and Mid… [+2875 chars]'},
#   {'source': {'id': 'ign', 'name': 'IGN'},
#    'author': 'Christian Wait',
#    'title': 'UK Deals: TCL Limited Time Offers On TVs Is Live',
#    'description': 'TCL’s limited-time UK sale offers TVs from budget to premium models, perfect for console gamers. Save big on a new setup as of Dec. 3.',
#    'url': 'https://www.ign.com/articles/uk-deals-tcl-limited-time-offers-on-tvs-is-live',
#    'urlToImage': 'https://assets-prd.ignimgs.com/2024/12/03/airpods-max-hero-5-1733232102889.png?width=1280',
#    'publishedAt': '2024-12-03T13:27:36Z',
#    'content': "It's time to upgrade your gaming TV, yes you. TCL has just kicked off a limited-time sale on their gaming ready TVs in the UK and there's something for everyone. Need a budget upgrade from that old 1… [+3131 chars]"}]}

# %% [markdown]
# **Étapes à suivre :**
#
# - Explorer les résultats obtenus, en identifiant les titres et les descriptions des ar-
# ticles.
#
# - Sauvegarder les résultats dans un fichier CSV pour une utilisation ultérieure.

# %% [markdown]
# **3. Web scraping de textes**
#
# Dans cette partie, nous utiliserons un outil comme BeautifulSoup pour extraire des
# données textuelles à partir d’un site web.
#
# Étapes à suivre :
#
# - Choisir une source web adaptée (par exemple, un blog ou un site d’actualités).
# - Identifier les balises HTML contenant les informations à extraire (par exemple, les
# titres des articles).
# - Extraire les données textuelles et les afficher.
# - Enregistrer les données extraites dans un fichier CSV.

# %% [markdown]
# ***Beautiful Soup***
#
#  Beautiful Soup analyse le contenu HTML de la page Web et le collecte pour fournir des fonctionnalités d’itération, de recherche et de modification. Pour fournir ces fonctionnalités, il fonctionne avec un analyseur qui convertit le contenu en un arbre d’analyse.

# %%
pip install beautifulsoup4 # téléchargement
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Invalid requirement: '#'

# %% [markdown]
# Maintenant, nous sommes prêts à demander notre première page Web. Ce n’est rien de compliqué. Nous enregistrons l’URL que nous voulons scrapper dans la variable url, puis nous demandons l’URL (requests.get(url)). Ensuite, nous enregistrons la réponse dans la variable response :

# %%
# Assign URL
#url = "https://www.geeksforgeeks.org/"
url="https://www.amazon.fr/gp/bestsellers/electronics/?ie=UTF8&ref_=sv_cag_1"


# Make a GET request 
response = requests.get(url)

# %%
print(response)
# Out:
# <Response [503]>

# %%
html = response.content # contenu HTML de la page web demandée
print(html)
# Out:
# b'<!DOCTYPE html>\n<!--[if lt IE 7]> <html lang="fr" class="a-no-js a-lt-ie9 a-lt-ie8 a-lt-ie7"> <![endif]-->\n<!--[if IE 7]>    <html lang="fr" class="a-no-js a-lt-ie9 a-lt-ie8"> <![endif]-->\n<!--[if IE 8]>    <html lang="fr" class="a-no-js a-lt-ie9"> <![endif]-->\n<!--[if gt IE 8]><!-->\n<html class="a-no-js" lang="fr"><!--<![endif]--><head>\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n<meta charset="utf-8">\n<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n<title dir="ltr">Amazon.fr</title>\n<meta name="viewport" content="width=device-width">\n<link rel="stylesheet" href="https://images-na.ssl-images-amazon.com/images/G/01/AUIClients/AmazonUI-3c913031596ca78a3768f4e934b1cc02ce238101.secure.min._V1_.css">\n<script>\n\nif (true === true) {\n    var ue_t0 = (+ new Date()),\n        ue_csm = window,\n        ue = { t0: ue_t0, d: function() { return (+new Date() - ue_t0); } },\n        ue_furl = "fls-eu.amazon.fr",\n        ue_mid = "A13V1IB3VIYZZH",\n        ue_sid = (document.cookie.match(/session-id=([0-9-]+)/) || [])[1],\n        ue_sn = "opfcaptcha.amazon.fr",\n        ue_id = \'4WQHR50S3JRNJJTZXX7T\';\n}\n</script>\n</head>\n<body>\n\n<!--\n        To discuss automated access to Amazon data please contact api-services-support@amazon.com.\n        For information about migrating to our APIs refer to our Marketplace APIs at https://developer.amazonservices.fr/ref=rm_c_sv, or our Product Advertising API at https://partenaires.amazon.fr/gp/advertising/api/detail/main.html/ref=rm_c_ac for advertising use cases.\n-->\n\n<!--\nCorreios.DoNotSend\n-->\n\n<div class="a-container a-padding-double-large" style="min-width:350px;padding:44px 0 !important">\n\n    <div class="a-row a-spacing-double-large" style="width: 350px; margin: 0 auto">\n\n        <div class="a-row a-spacing-medium a-text-center"><i class="a-icon a-logo"></i></div>\n\n        <div class="a-box a-alert a-alert-info a-spacing-base">\n            <div class="a-box-inner">\n                <i class="a-icon a-icon-alert"></i>\n                <h4>Saisissez les caract\xc3\xa8res que vous voyez ci-dessous</h4>\n                <p class="a-last">D\xc3\xa9sol\xc3\xa9s, il faut que nous nous assurions que vous n\'\xc3\xaates pas un robot. Pour obtenir les meilleurs r\xc3\xa9sultats, veuillez vous assurer que votre navigateur accepte les cookies.</p>\n                </div>\n            </div>\n\n            <div class="a-section">\n\n                <div class="a-box a-color-offset-background">\n                    <div class="a-box-inner a-padding-extra-large">\n\n                        <form method="get" action="/errors/validateCaptcha" name="">\n                            <input type=hidden name="amzn" value="cAzFB+SiboBvfqHQPnmyTQ==" /><input type=hidden name="amzn-r" value="&#047;gp&#047;bestsellers&#047;electronics&#047;?ie&#061;UTF8&amp;ref_&#061;sv_cag_1" />\n                            <div class="a-row a-spacing-large">\n                                <div class="a-box">\n                                    <div class="a-box-inner">\n                                        <h4>Saisissez les caract\xc3\xa8res que vous voyez dans cette image :</h4>\n                                        <!-- For automated access to price change or offer listing change events,\n                                             please refer to the MWS Subscription API:\n                                             https://developer.amazonservices.fr/gp/mws/api.html/277-5993977-7749460?ie=UTF8&section=subscriptions&group=subscriptions&version=latest\n                                        -->\n                                        <div class="a-row a-text-center">\n                                            <img src="https://images-na.ssl-images-amazon.com/captcha/derqnxxq/Captcha_wadyerzkub.jpg">\n                                        </div>\n                                        <div class="a-row a-spacing-base">\n                      ...

# %% [markdown]
# Le résultat est le contenu HTML de la page de la liste des meilleures ventes High Tech d’Amazon, mais il est vraiment difficile à lire à l’œil humain.

# %%
from bs4 import BeautifulSoup as bs
soup = bs(html, "lxml") # objet Beautiful Soup nommé soup 
# html (qui est la variable où nous avons enregistré le contenu HTML 
# difficile à lire à partir de l’URL de la page blog), le second paramètre
#  (« lxml« ) est l’analyseur syntaxique qui est utilisé sur la variable html.

# %%
soup # plus agréable à l’œil
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html lang="fr" class="a-no-js a-lt-ie9 a-lt-ie8 a-lt-ie7"> <![endif]--><!--[if IE 7]>    <html lang="fr" class="a-no-js a-lt-ie9 a-lt-ie8"> <![endif]--><!--[if IE 8]>    <html lang="fr" class="a-no-js a-lt-ie9"> <![endif]--><!--[if gt IE 8]><!--><html class="a-no-js" lang="fr"><!--<![endif]--><head>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title dir="ltr">Amazon.fr</title>
# <meta content="width=device-width" name="viewport"/>
# <link href="https://images-na.ssl-images-amazon.com/images/G/01/AUIClients/AmazonUI-3c913031596ca78a3768f4e934b1cc02ce238101.secure.min._V1_.css" rel="stylesheet"/>
# <script>
#
# if (true === true) {
#     var ue_t0 = (+ new Date()),
#         ue_csm = window,
#         ue = { t0: ue_t0, d: function() { return (+new Date() - ue_t0); } },
#         ue_furl = "fls-eu.amazon.fr",
#         ue_mid = "A13V1IB3VIYZZH",
#         ue_sid = (document.cookie.match(/session-id=([0-9-]+)/) || [])[1],
#         ue_sn = "opfcaptcha.amazon.fr",
#         ue_id = '4WQHR50S3JRNJJTZXX7T';
# }
# </script>
# </head>
# <body>
# <!--
#         To discuss automated access to Amazon data please contact api-services-support@amazon.com.
#         For information about migrating to our APIs refer to our Marketplace APIs at https://developer.amazonservices.fr/ref=rm_c_sv, or our Product Advertising API at https://partenaires.amazon.fr/gp/advertising/api/detail/main.html/ref=rm_c_ac for advertising use cases.
# -->
# <!--
# Correios.DoNotSend
# -->
# <div class="a-container a-padding-double-large" style="min-width:350px;padding:44px 0 !important">
# <div class="a-row a-spacing-double-large" style="width: 350px; margin: 0 auto">
# <div class="a-row a-spacing-medium a-text-center"><i class="a-icon a-logo"></i></div>
# <div class="a-box a-alert a-alert-info a-spacing-base">
# <div class="a-box-inner">
# <i class="a-icon a-icon-alert"></i>
# <h4>Saisissez les caractères que vous voyez ci-dessous</h4>
# <p class="a-last">Désolés, il faut que nous nous assurions que vous n'êtes pas un robot. Pour obtenir les meilleurs résultats, veuillez vous assurer que votre navigateur accepte les cookies.</p>
# </div>
# </div>
# <div class="a-section">
# <div class="a-box a-color-offset-background">
# <div class="a-box-inner a-padding-extra-large">
# <form action="/errors/validateCaptcha" method="get" name="">
# <input name="amzn" type="hidden" value="cAzFB+SiboBvfqHQPnmyTQ=="/><input name="amzn-r" type="hidden" value="/gp/bestsellers/electronics/?ie=UTF8&amp;ref_=sv_cag_1"/>
# <div class="a-row a-spacing-large">
# <div class="a-box">
# <div class="a-box-inner">
# <h4>Saisissez les caractères que vous voyez dans cette image :</h4>
# <!-- For automated access to price change or offer listing change events,
#                                              please refer to the MWS Subscription API:
#                                              https://developer.amazonservices.fr/gp/mws/api.html/277-5993977-7749460?ie=UTF8&section=subscriptions&group=subscriptions&version=latest
#                                         -->
# <div class="a-row a-text-center">
# <img src="https://images-na.ssl-images-amazon.com/captcha/derqnxxq/Captcha_wadyerzkub.jpg"/>
# </div>
# <div class="a-row a-spacing-base">
# <div class="a-row">
# <div class="a-column a-span6">
# </div>
# <div class="a-column a-span8 a-span-last a-text-right">
# <a onclick="window.location.reload()">Essayez une autre image</a>
# </div>
# </div>
# <input autocapitalize="off" autocomplete="off" autocorrect="off" class="a-span12" id="captchacharacters" name="field-keywords" placeholder="Saisissez les caractères suivants" spellcheck="false" type="text"/>
# </div>
# </div>
# </div>
# </div>
# <div class="a-section a-spacing-extra-large">
# <div class="a-row">
# <span class="a-button a-button-primary a-span12">
# <span class="a-button-inner">
# <button class="a-button-text" type="submit">Continuer les achats</button>
# </span>
# </span>
# </div>
# </div>
# </form>
# </div>
# </div>
# </div>
# </div>
# <div class="a-divider a-divider-section"><div class="a-divider-inner"></div></div>
# <div class="a-text-center a-spacing-small a-size-mini">
# <a href="https://www.amazon.fr/gp/help/customer/display.html/ref=footer_cou?ie=UTF8&amp;nodeId=548524">Conditions générales de vente</a>
# <span class="a-letter-space"></span>
# <span class="a-letter-space"></span>
# <span class="a-letter-space"></span>
# <span class="a-letter-space"></span>
# <a href="https://www.amazon.fr/gp/help/customer/display.html/ref=footer_privacy?ie=UTF8&amp;nodeId=3329781">Vos informations personnelles</a>
# </div>
# <div class="a-text-center a-size-mini a-color-secondary">
#           © 1996-2015, Amazon.com, Inc. ou ses filiales.
#           <script>
#            if (true === true) {
#              document.write('<img src="https://fls-eu.amaz'+'on.fr/'+'1/oc-csi/1/OP/requestId=4WQHR50S3JRNJJTZXX7T&js=1" />');
#            };
#           </script>
# <noscript>
# <img src="https://fls-eu.amazon.fr/1/oc-csi/1/OP/requestId=4WQHR50S3JRNJJTZXX7T&amp;js=0"/>
# </noscript>
# </div>
# </div>
# <script>
#     if (true === true) {
#         var head = document.getElementsByTagName('head')[0],
#             prefix = "https://images-eu.ssl-images-amazon.com/images/G/01/csminstrumentation/",
#             elem = document.createElement("script");
#         elem.src = prefix + "csm-captcha-instrumentation.min.js";
#         head.appendChild(elem);
#
#         elem = document.createElement("script");
#         elem.src = prefix + "rd-script-6d68177fa6061598e9509dc4b5bdd08d.js";
#         head.appendChild(elem);
#     }
#     </script>
# </body></html>

# %% [markdown]
# Cela donne une structure de données imbriquée du contenu HTML original dans laquelle nous pouvons facilement naviguer et collecter des données.
